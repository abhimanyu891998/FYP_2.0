# %% [markdown]
# <a href="https://colab.research.google.com/github/abhimanyu891998/FYP_2.0/blob/master/Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.python.keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# %%
dataframe = pandas.read_csv("user_a.csv", error_bad_lines = False, skiprows=1 ,header=None)
dataset = dataframe.values
X = dataset[1:, 1:].astype(float)
Y = dataset[1:, 0]
print(Y.shape)
print(X.shape)
# Out:
# (3381,)
# (3381, 112)
# b'Skipping line 507: expected 113 fields, saw 114\nSkipping line 1011: expected 113 fields, saw 158\n'

# %%
model = Sequential()
model.add(Dense(12, input_dim=112, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) 
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 227/227 [==============================] - 1s 3ms/step - loss: 1.2735e-07 - accuracy: 0.3625 - val_loss: 1.0218e-07 - val_accuracy: 0.2867
# Epoch 2/150
# 227/227 [==============================] - 0s 2ms/step - loss: 1.2724e-07 - accuracy: 0.3625 - val_loss: 1.0218e-07 - val_accuracy: 0.2867
# Epoch 3/150
# 227/227 [==============================] - 0s 2ms/step - loss: 1.2740e-07 - accuracy: 0.3625 - val_loss: 1.0218e-07 - val_accuracy: 0.2867
# Epoch 4/150
# 227/227 [==============================] - 0s 2ms/step - loss: 1.2740e-07 - accuracy: 0.3625 - val_loss: 1.0218e-07 - val_accuracy: 0.2867
# Epoch 5/150
# 227/227 [==============================] - 0s 2ms/step - loss: 1.2730e-07 - accuracy: 0.3625 - val_loss: 1.0218e-07 - val_accuracy: 0.2867
# Epoch 6/150
# 227/227 [==============================] - 0s 2ms/step - loss: 1.2740e-07 - accuracy: 0.3625 - val_loss: 1.0218e-07 - val_accuracy: 0.2867
# Epoch 7/150
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-78f56578439b> in <module>()
# ----> 1 results = cross_val_score(estimator, X, Y, cv=kfold)
#       2 print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     388                                 fit_params=fit_params,
#     389                                 pre_dispatch=pre_dispatch,
# --> 390                                 error_score=error_score)
#     391     return cv_results['test_score']
#     392
#
# ...
